# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/en/f/fb/SETU_Ireland_logo.png" alt="SETU" width="1000"/>

# %% [markdown]
# # Palmer Archipelago Penguin Data Set
# *****

# %% [markdown]
# * Author: John Paul Lee
# * Github: JPLee01
# * Email: C00244423@itcarlow.ie
# * Created: 08-11-2022, Last update: 09-11-2022
# * Research Method for Engineering: Data Analysis and Visualisation 30%.
# ***
# **Lecturer:** Dr. Edmond Tobin
#
# * This Jupyter Notebook has been created to offer a report on the Palmer Archipelago Penguin Data Set. This report will provide an overview of the data set, examine the data set in terms of variables, execute normality, homogeneity and post hoc tests. Provide plots and visualisations as necessary.
#
# ***
# As part of the assignment this report will deal with four main tasks:
#
# 1. An analysis of the 4 dependent variables within the Data Set.
# 2. Execution of normality and homogeneity tests.
# 3. Execution of post hoc tests.
# 4. Creation of plots and visualisations as necessary.

# %% [markdown]
# **Table of Contents**
# ------------------------------------------------------------------------------------------------
#
# [Penguin Data Set](#penguin-data-set)
#
# [1. Introduction](#1-introduction)
#
# [2. Penguin Data Set](#2-penguin-data-set)
#
#   [2.1 Background](#2.1-Background)
#
# [3. Problem Statement](#3-Problem-Statement)
#
# [4. Previous Case Studies of the Data Set](#4-Previous-Case-Studies-of-the-Data-Set)
#
# [5. Issues and Inconsistencies with Data Set](#5-Issues-and-Inconsistencies-with-Data-Set)
#
# [6. Libraries](#6-Libraries)
#
# [7. Analysis of Data Set and Results Explained](#7-Analysis-of-Data-Set-and-Results-Explained)
#
#   [7.1 Initial Analysis](#7.1-Initial-Analysis)
#
#   [7.2 Analysis of Dependent Variables](#7.2-Analysis-of-Dependent-Variables)
#
#   [7.3 Normality Analysis](#7.3-Normality-Analysis)
#
#   [7.4 Homogeneity Analysis](#7.4-Homogeneity-Analysis)
#
#   [7.5 Post Hoc Analysis](#7.5-Post-Hoc-Analysis)
#
# [8. Summary, Conclusion and Future Possibilities for the Data Set](#8-Summary,-Conclusion-and-Future-Possibilities-for-the-Data-Set)
#
# [9. References](#9-References)
#
# [10. Bibliography](#10-Bibliography)

# %% [markdown]
# ## 1 Introduction
# ------------------------------------------------------------------------------------------------
#
# This analysis of Penguin Data Set has been carried out as an assignment of the Research Methods Module. The aim of this assignment is to help the student gain a practical experience in data handling, including data types and structures handling, data splicing, plots generation and interpretation.

# %% [markdown]
# ## 2 Palmer Archipelago Penguin Iris Data Set
# ------------------------------------------------------------------------------------------------
# ### 2.1 Background
# The data analysed in this report is the Palmer Archipelago Penguin Data Set (Gorman et al., 2014).The Penguin Data Set collected from 2007 to 2009 by Dr. Kristen Gorman with the Palmer Station Long Term Ecological Research Program, part of the US Long Term Ecological Research Network (Hill et al., 2020). Body size measurements were collected for three species of Pygoscelis penguins that breed on islands throughout the Palmer Archipelago, Antarctica (Gorman et al., 2021). The three species of Pygoscelis penguins can be seen in the image below:
#
# ![Penguin Species](https://education.rstudio.com/blog/2020/07/palmerpenguins-cran/gorman-penguins.jpg)
#
# Three hundred and fourty four observations were collected and analysed. Within each observation, Gorman studied five distinct characteristics:
#
# 1.  Bill Length (Mm)
# 2.  Bill Depth (Mm)
# 3.  Flipper Length (Mm)
# 4.  Body Mass (G)
# 5.  Sex
#
# These observations were taken over the following three islands of the Palmer Archipelago:
# 1. Biscoe
# 2. Dream
# 3. Torgersen
#
# It should be noted that the year these observations took place is also included in the data set.

# %% [markdown]
# ##  3 Problem Statement
# ------------------------------------------------------------------------------------------------
# As part of the assignment, the student was given a set of instructions. Within the instructions a problem statement was printed. It stated that this assignment will involve an analysis of the Palmer Archipelago Penguin Data Set. Python code will be utilised for this analysis and the student will give explanations of the python code and discuss any observations. The problem statement also explained it was required for the project to:
#
# * Produce a statistical analysis report of the data and present a series of graphs of the data that would be in a form suitable for publication in a journal paper or other formal report.
# * Analyse all 4 dependent variables.
# * Perform normality and homogeneity tests, and if required, post hoc tests.
# * The report should provide a discussion on the significance of the data and data set.
# * The student can use any statistical software that they are familiar with.

# %% [markdown]
# ##  4 Previous Case Studies of the Data Set
# ------------------------------------------------------------------------------------------------
# Through an online search it can be seen that a number of previous iterations of the analysis of the data have taken place. These include programs written in Python as well as other computing languages. The works of Tsai (2021) and Tirendaz Academy (2022) who demonstrate the use of Pandas, Numpy, Matplotlib and Seaborn for management of the Palmer Archipelago Penguin Data Set were used as inspiration by the author in the construction of the report.

# %% [markdown]
# ##  5 Issues within the Data Set
# ------------------------------------------------------------------------------------------------
# It should be noted, that there are a number of issues within the data set sourced provided to the author and the data set presented by Gorman (2014) et al. These issues are as follows:
#
# 1.  4th Sample:  Null values in every column except species, island and year.
# 2.  9th Sample:  Null sex value.
# 3.  10th Sample: Null sex value.
# 4.  11th Sample: Null sex value.
# 5.  12th Sample: Null sex value.
# 6.  48th Sample: Null sex value.
# 7.  179th Sample: Null sex value.
# 8.  219th Sample: Null sex value.
# 9.  257th Sample: Null sex value.
# 10. 269th Sample: Null sex value.
# 11. 272nd Sample:  Null values in every column except species, island and year.
#
# These issues will be handled by the author later on in the report.

# %% [markdown]
# ##  6 Libaries
# ------------------------------------------------------------------------------------------------
# The following Python libraries were used in the writing of the programs code and are required to successfully run the notebook:
# * [Numpy](https://www.numpy.org/) - Used for synthesisation of the data and mathematical functions.
# * [Pandas](https://pandas.pydata.org/) - Used for import, management, data manipulation and analysis.
# * [Matplotlib.pyplot](https://matplotlib.org/tutorials/introductory/pyplot.html) - Used for the manipulation of elements and the creation of certain plots graphs, plots and charts.
# * [Seaborn](https://seaborn.pydata.org/) - Used for the creation and manipulation of all plots created. (Seaborn allows for the extetion of the functionality of Matplotlib).
# * [Scikit-Learn](https://scikit-learn.org/stable/) - A machine learning library for the Python programming language. The use of this library is explored within the notebook.

# %% [markdown]
# ## 7 Analysis of Data Set and Results Explained
# ------------------------------------------------------------------------------------------------
# This section will describe the Python programs and subsequent code which was created to analyse the data set as well as a discussion on the results these programs yielded.
#
# For clarity comments within the code have been added by the author to offer the reader an understanding of the specifics of the Python programs created.

# %% [markdown]
# ### 7.1 Initial Analysis
# This section will be concerned with the loading of the necessary libraries, the importing the data set and creation of a DataFrame as well as an initial analysis of the contents of the data set.
#
# #### Importing the Libraries
# As seen above a munber of libraries are required to successfully write and run the programs code. For the notebook the following libraries were imported:

# %%
#Importation of the necessary libraries

#Import Numpty for Analysis of the data 
import numpy as np

#Import Pandas for Data Management 
import pandas as pd 

#Import matplotlib.pyplot and seaborn for Visualisation of the data
import matplotlib.pyplot as plt
import seaborn as sns

#Import Scikit-Learn for Machine Learning of the data
import sklearn

# %% [markdown]
# Point to note ss we will be displaying Plots in this Jupyter Notebook we will implement the inline magic command to allow the Plots to be rendered inline within the Notebook (Rishabh, 2017).

# %%
#Inline Magic command implemented to ensure that the Plots are rendered inline
# %matplotlib inline

# %% [markdown]
# To ensure uniformity throughout the Juypter Notebook with regard to Seaborn Plots display, the style and palette fuction will be set.
#
# The style function will be set to darkgrid. This will allow for optimal measurements of Plots, as the darkened background with the built in grid lines will be best displayed against the white background of the Juypter Notebook.(Geek for Geeks, 2021). The palette fuction will be set to bright, as it will allow for clear distinction of multiple outputs within one Plot (Geek for Geeks, 2021). Finally, in order to ensure uniformity throughout the notebook the plots size will be set using the rcParams function (Dou, 2020).

# %%
#Setting of Seaborn dispays to enure uniformity throughout the Juypter Notebook

#Darkplot style selected to allow for optimal measurments of Plots
sns.set_style("darkgrid")
#Bright colour palette selected to allow for clear distinction of multiple outputs within one Plot 
sns.set_palette("bright")

# set plot style
plt.style.use("ggplot")

# Increase the size of the output plots
plt.rcParams["figure.figsize"] = (12,8)

# %% [markdown]
# #### Importing the Data Set and Creation of a DataFrame
# The data set is imported from the Csv file through the use of the pandas.read function. Once imported this data set is used in the creation of a DataFrame to allow for greater ease of analysis.

# %%
#Import the data
f = pd.read_csv("Penguin.csv")

#Create a DataFrame from the Csv file to allow for easier analysis
df = pd.DataFrame(f)

#Copy of the original data set kept in case required
dfc = pd.DataFrame(f)

#Display the shape of the DataFrame
(df.shape)
# Out:
# (344, 8)

# %% [markdown]
# As can be seen from the shape the the data set contains three hundred and fourty four observations with eight variables.

# %% [markdown]
# #### List of the Unique Values in the Data Set
# To create a list of the unique values in the categorical columns the following code is executed:

# %%
#Unique Values in the Species Column
Specieslist = df["species"].unique()
print ("The Species present in this dataset are:")
for i in Specieslist:
    print('>', i)
print()
    
#Unique Values in the Island Column
Islandlist = df["island"].unique()
print ("The Islands present in this dataset are:")
for i in Islandlist:
    print('>', i)
print()

#Unique Values in the Sex Column
Genderlist = df["sex"].unique()
print ("The Sex types present in this dataset are:")
for i in Genderlist:
    print('>', i)
# Out:
# The Species present in this dataset are:
# > Adelie
# > Gentoo
# > Chinstrap
#
# The Islands present in this dataset are:
# > Torgersen
# > Biscoe
# > Dream
#
# The Sex types present in this dataset are:
# > male
# > female
# > nan

# %% [markdown]
# As can be seen from the results it appears a third sex type value is present. This lends itself to the assumption that there may be some inconsistencies within the data set. As a result, an exploration of this will now take place (Data to Fish, 2021). Firstly the Pandas.DataFrame.head command will be implemented to display the first 5 rows of data to see if any Nan (not a number/null) values are present.

# %%
#Display the first 5 rows of data
print("The follwoing are the first 5 rows of data within the data set:")
df.head()
# Out:
# The follwoing are the first 5 rows of data within the data set:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex  year
# 0       3750.0    male  2007
# 1       3800.0  female  2007
# 2       3250.0  female  2007
# 3          NaN     NaN  2007
# 4       3450.0  female  2007

# %% [markdown]
# As can be seen row 3 (4th observation but to the rows beginning at 0) null values in every column except species, island and year. As a result, code will be implemented which will highlight all rows which have a NaN value.

# %%
#Highlight all rows which have a NaN value
nan_values = df[df.isnull().any(axis=1)]

#Print the results
print("The follwoing are the observations with null values within the data set: \n")
nan_values
# Out:
# The follwoing are the observations with null values within the data set:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 8    Adelie  Torgersen            34.1           18.1              193.0
# 9    Adelie  Torgersen            42.0           20.2              190.0
# 10   Adelie  Torgersen            37.8           17.1              186.0
# 11   Adelie  Torgersen            37.8           17.3              180.0
# 47   Adelie      Dream            37.5           18.9              179.0
# 178  Gentoo     Biscoe            44.5           14.3              216.0
# 218  Gentoo     Biscoe            46.2           14.4              214.0
# 256  Gentoo     Biscoe            47.3           13.8              216.0
# 268  Gentoo     Biscoe            44.5           15.7              217.0
# 271  Gentoo     Biscoe             NaN            NaN                NaN
#
# ...

# %% [markdown]
# From the output we can see that eleven observtions have Nan (not a number/null) values. These range from a single entry e.g. sex, in an observation, to every entries except species, island and year. This also reinforces the issues highlighed in section 5 of the report

# %% [markdown]
# #### Treatment of Null Vlaues
# When analysing a data set it is important to deal with null values. This is becasue if left untreated null values can adversely affect the accuracy of resluts/hypotheses as well as potentially building a biased machine learning algorithms (Kumar, 2019). When data wrangling (removing errors and combining data sets to make them more accessible and easier to analyze (Simplilearn, 2022)), two primary methods can be implemented; the imputation or the removal of data (Swalin, 2018).
#
# The imputation of data is a technique used for replacing the missing data with some substitute value to retain most of the data/information of the dataset i.e. developing a reasonable guess for the missing data (Singhal, 2021). This technique ia most useful when the percentage of missing data is low. However if, the portion of missing data is too high, the results lack natural variation that could result in an effective model (MastersInDataScience.org, 2022). Examples of imputation techniques include; Mean imputation (replacing the missing value withe the mean (Schork, 2019) and Cold deck imputation (replacing the missing value with a value collected from a similiar study (Maity, 2020).
#
# The removal of data simply mean the removal of the observations with the missing data from the data set (Madaan, 2022). While it can be argued the removal of data versus the imputation of data reduces bias, removing data may not be the best option if there are not enough observations to result in a reliable analysis (Gawali, 2021).
#
# It is the author opinion that for the purpose of this assignment the imputation of data is most suitable technique to use. This is due to the fact that the overall presentage of missing data is less than 1% (19 missing values out of a total of 2752) and machine learning techniques offer an effective method to impute missing values. The author will implement the Sklearn KNN Imputer module to predict the missing values. It should be noted that the work of Dash (2022) was used for inspiration for the implementation of the Sklearn KNN Imputer.

# %% [markdown]
# #### Implementation of Sklearn KNN Imputer on Null Vlaues
# KNN Imputer is a scikit-learn class used to fill out or predict the missing values in a dataset (Geek for Geeks, 2020b).The KNN Imputer class uses the k-Nearest Neighbors approach for calculating the missing values (Brownlee, 2020b). That is to say ‘k’ samples in the dataset that are similar or close to the missing data are identified, the mean value of these ‘k’ samples are used to predict the missing values (Chowdhury, 2020).
#
# It should be noted that the KNN Imputer does not work with object datatypes e.g. string, array, class. As a result all the object data will need to be converted to an integer type via sklearn’s LabelEncoder (The Data Detective, 2019).
#
# The implement the Sklearn KNN Imputer module can be seen in the code below.
#
# Please note that when implementing the Sklearn KNN Imputer module on the DataFrame copy a Python Warning appears. This particular warning "SettingWithCopyWarning" states that - A value is trying to be set on a copy of a slice from a DataFrame. Explained in great details in a DataQuest blog (2017) that warning essentially informs that user that they may be modifying a copy of a DataFrame but not the original DataFrame (this can be seen in the image below). When implementing the Sklearn KNN Imputer module it is the authors intention to modify to copied DataFrame (dfc) and leave the original DataFrame (df) to allow for comparassion. As a result, for aesthetic purposes the author will implement the Python warnings ignore function (Stack Overflow, 2012).

# %% [markdown]
# ![SettingWithCopyWarning](https://www.dataquest.io/wp-content/uploads/2019/01/modifying.png)

# %%
#Import the warnings ignore function for aesthetic purposes
import warnings
warnings.filterwarnings('ignore')

#Import KNNImputer and LabelEncoder from the sklearn library
from sklearn.impute import KNNImputer
from sklearn.preprocessing import LabelEncoder

#Encode and Impute the data
encode = LabelEncoder()
impute = KNNImputer()
for i in df.select_dtypes(include='object').columns:
    df[i][df[i].notnull()] = encode.fit_transform(dfc[i])

# %% [markdown]
# The Pandas.DataFrame.head command will be implemented will now be implemented again to observed how the data has been encoded.

# %%
#Use of Pandas.DataFrame.head command again to see how data is encoded
df.head()
# Out:
#   species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       0      2            39.1           18.7              181.0
# 1       0      2            39.5           17.4              186.0
# 2       0      2            40.3           18.0              195.0
# 3       0      2             NaN            NaN                NaN
# 4       0      2            36.7           19.3              193.0
#
#    body_mass_g  sex  year
# 0       3750.0    1  2007
# 1       3800.0    0  2007
# 2       3250.0    0  2007
# 3          NaN  NaN  2007
# 4       3450.0    0  2007

# %% [markdown]
# From the output it can be observed that the variables in the columns are not scaled properly. This can potentially lead to issues in terms of data analysis such as modelling the data. As a result, the Sklearn MinMaxScaler module will be implemented to to normalize the variables (Brownlee, 2020a).

# %%
#Use of Sklearn MinMaxScaler module to sclae the data
from sklearn.preprocessing import MinMaxScaler
sca = MinMaxScaler()
df_sca = pd.DataFrame(sca.fit_transform(df),columns=dfc.columns)

#Print first five obervation to see if normalization has taken place
df_sca.head()
# Out:
#    species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0      0.0     1.0        0.254545       0.666667           0.152542
# 1      0.0     1.0        0.269091       0.511905           0.237288
# 2      0.0     1.0        0.298182       0.583333           0.389831
# 3      0.0     1.0             NaN            NaN                NaN
# 4      0.0     1.0        0.167273       0.738095           0.355932
#
#    body_mass_g  sex  year
# 0     0.291667  1.0   0.0
# 1     0.305556  0.0   0.0
# 2     0.152778  0.0   0.0
# 3          NaN  NaN   0.0
# 4     0.208333  0.0   0.0

# %% [markdown]
# As the data is now scaled correctly imputation can now take place.

# %%
#Imputation of the data
new_df = pd.DataFrame(impute.fit_transform(df_sca), columns=dfc.columns)

#Run the isnull function to observe is there are any remaining null values
print("")
new_df.isnull().sum()
# Out:
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# year                 0
# dtype: int64

# %% [markdown]
# From running the isnull function it can be seen that there are no null values remaining. As a result, the variables can now be rescaled back to thier original values and the categorical data back to its original form e.g. 0 - Female, 1 - Male. The first five observations will now be printed to observe any changes.

# %%
#Rescale of data to original values and categorical data back to original form
dt = pd.DataFrame(sca.inverse_transform(new_df),columns=df.columns)
dt['sex'] = dt['sex'].round()
dt['sex'] = dt['sex'].map({0:'Female', 1:'Male'})
dt['species'] = dt['species'].map({0:'Adeile',1:'Chinstrap',2:'Gentoo'})
dt['island'] = dt['island'].map({0:'Biscoe',1:'Dream',2:'Torgersen'})

#Print first five observations to see changes
dt.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adeile  Torgersen            39.1          18.70              181.0
# 1  Adeile  Torgersen            39.5          17.40              186.0
# 2  Adeile  Torgersen            40.3          18.00              195.0
# 3  Adeile  Torgersen            38.3          19.46              191.2
# 4  Adeile  Torgersen            36.7          19.30              193.0
#
#    body_mass_g     sex    year
# 0       3750.0    Male  2007.0
# 1       3800.0  Female  2007.0
# 2       3250.0  Female  2007.0
# 3       3960.0  Female  2007.0
# 4       3450.0  Female  2007.0

# %% [markdown]
# As seen from the first five observations the null values have been replaced and original values have been rescaled in the copied DataFrame (dfc) which can now be used for analysis. I should be noted (as seen below) that the original DataFrame (df) is still accessable can can be called for comparassion if required.

# %%
#Rescale of original data to its original form
df = pd.DataFrame(sca.inverse_transform(df_sca),columns=df.columns)
df['sex'] = df['sex'].round()
df['sex'] = df['sex'].map({0:'Female', 1:'Male'})
df['species'] = df['species'].map({0:'Adeile',1:'Chinstrap',2:'Gentoo'})
df['island'] = df['island'].map({0:'Biscoe',1:'Dream',2:'Torgersen'})

#Print first five observations 
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adeile  Torgersen            39.1           18.7              181.0
# 1  Adeile  Torgersen            39.5           17.4              186.0
# 2  Adeile  Torgersen            40.3           18.0              195.0
# 3  Adeile  Torgersen             NaN            NaN                NaN
# 4  Adeile  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex    year
# 0       3750.0    Male  2007.0
# 1       3800.0  Female  2007.0
# 2       3250.0  Female  2007.0
# 3          NaN     NaN  2007.0
# 4       3450.0  Female  2007.0

# %% [markdown]
# ### 7.2 Analysis of Dependent Variables
# Within the data set four dependent variables exist; Bill Length, Bill Depth, Flipper Length and Body Mass. Each of these variables will be explored in terms of thier distribution through normality tests. The homogeneity of the variables will then be examined and finally a finally post hoc tests will be conducted.

# %% [markdown]
# #### Creation of Sub-DataFrames
# Prior to any analysis taking place the author will first create a number of sub-DataFrames based on specific data e.g. Sex, Species etc. These will be created to ease the calling of data and the creation of specific Python scripts.

# %%
#Creation of Gender Specific Sub-DataFrame
MaleData = dt[dt.sex == "Male"]
FemaleData = dt[dt.sex == "Female"]

#Creation of Species Specific Sub-DataFrame
AdeileData = dt[dt.species == "Adeile"]
ChinstrapData = dt[dt.species == "Chinstrap"]
GentooData = dt[dt.species == "Gentoo"]

# %% [markdown]
# #### Analysis of the Normality of the Data Set
# Within statistics normality is concerned with analysing the distribution of the data set and seeing does it conform to a normal distribution (Mishra and et al, 2012). A normal distribution, also known as Gaussian distribution, named after the German mathematician Carl Friedrich Gauss, is viewed as one of the most important probability distributions.(w3shools.com, 2019; Frost, 2018).This is due to the fact that it fits many natural phenomena such as; heights, blood pressure, measurement error, and IQ scores. (McLeod, 2019). The normal distribution is a probability function that describes how the values of a variable are distributed. It is a symmetric distribution where most of the observations cluster around the central peak and the probabilities for values move away from the mean taper off equally in both directions. Extreme values in both tails of the distribution are similarly unlikely. As a result it is known as the Bell Curve (Weisstein, 2016). An example of a normal distribution can be seen in the image below:
#
# ![Normal Distribution](https://www.isixsigma.com/wp-content/uploads/2018/11/Screen-Shot-2022-06-13-at-10.20.58-AM.png)
#
# It should be noted that every normal distribution curve, regardless of its mean or standard deviation, conforms to the 68-95-99.7 rule (Berman, 2021). This is that:
#    * About 68% of the area under the curve falls within 1 standard deviation of the mean.
#    * About 95% of the area under the curve falls within 2 standard deviations of the mean.
#    * About 99.7% of the area under the curve falls within 3 standard deviations of the mean.
#
# It is important the normality of a data set is measured as a number of theoretical statistical methods are based on the assumption that the data is normally distributed (Ghasemi1 and Zahediasl, 2012).
#
# In order to analyse the normality of the data set the author will first use the matplotlib.pyplot.hist() function to plot a histogram of each of the dependant variables (Geek for Geeks, 2020a) accross the species and genders. It should be noted the within a histogram the X-axis displays the scale of values which the measurements fall under, while the Y-axis displays the number of times that the values occurred within the intervals set by the X-axis (CFI, 2022a). The histogram can be used to visually assess if the data is normally distributed (Solomon, 2018). Once this is completed the author will then focus on each dependent variable seperately.

# %% [markdown]
# #### Construction of Histograms of the Dependant Variables
# For the construction of the histograms the author will use the following colour code to identify the DataFrame/sub-DataFrame being used:
#    * All Genders - Green
#    * Male - Blue
#    * Female - Red
#    * Adeile - Purple
#    * Chinstrap - Olive
#    * Gentoo - Brown

# %%
#Construction of Histograms of the Dependant Variables

#All Genders Histogram
dt.hist(figsize=(25,25), color="green")
plt.suptitle("Histogram Plot for all Dependent Variables", fontsize=25)
# Out:
# Text(0.5, 0.98, 'Histogram Plot for all Dependent Variables')

# %% [markdown]
# From the results of the histogram for all Dependent Variables it can be seen that the year the observation took place has been included. As this does not offer any real meanginful data in terms of the histogram output and aesthetically is not the most pleasing the author will remove it from future histogram outputs. To do this the author will slice the Sub-DataFrame to include just the columns; Bill Length, Bill Depth, Flipper Length and Body Mass i.e the four dependent variables.
#
# In terms of the analysis of the results it could be argued that the Bill Length and Bill Depth follow a slight normal distribution due to thier upper and lower tails being on the extremities of the values.

# %%
#Slicing of sub-DataFrame to remove the Year Column
dx = dt[['bill_length_mm', 'bill_depth_mm','flipper_length_mm', 'body_mass_g']]

#Naming of new sub-DataFrames
MaleData2 = dx[dt.sex == "Male"]
FemaleData2 = dx[dt.sex == "Female"]
AllData = dx[dt.sex != "X"]

AdeileData2 = dx[dt.species == "Adeile"]
ChinstrapData2 = dx[dt.species == "Chinstrap"]
GentooData2 = dx[dt.species == "Gentoo"]

# %%
#Male Only Histogram
MaleData2.hist(figsize=(25,25), color="blue")
plt.suptitle("Histogram Plot for all Male Dependent Variables", fontsize=25)
# Out:
# Text(0.5, 0.98, 'Histogram Plot for all Male Dependent Variables')

# %% [markdown]
# It can be argued in terms of the results for the male dependent variables that none of them observe a normal distribution. This is due to the fact that for all dependent variables the highest measurments take place to the left or right of the distributions. These type of distributions it could be said mimic a skewed distribution. A skewed distribution is a distribution where the data is not spread evenly (i.e. normally distributed) and is clustered at one end (Tutor2U, 2019. A skewed distribution can be either positively or negatively skewed depending on the shape of the distribution. This can be seen in the image below:
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/f/f8/Negative_and_positive_skew_diagrams_%28English%29.svg/446px-Negative_and_positive_skew_diagrams_%28English%29.svg.png" alt="Skewed Distribution" width="900"/>
#
#
# From comparing the distribution with the above image we can see the distribution for the body follows a left (or negative) skewed distribution. In a positive skew the mass of the distribution is concentrated on the left of the figure, this means the right tail is longer (Glen, 2015). Unlike normally distributed data where all measures of central tendency (mean and median) equal each other, with skewed data, the measures are dispersed. The general relationship between the central tendency measures in a positively skewed distribution is that the mean will be greater than the median (and visa versa for a negatively skewed distribution) (CFI, 2022b). Examples of positively skewed distribution include the distribution of income and movie ticket sales per movie, while negatively skewed distributions can be found in areas such as finance particulary returns on investments and tax returns (Weisstein, 2018; Zach, 2021).

# %%
#Female Only Histogram
FemaleData2.hist(figsize=(25,25))
plt.suptitle("Histogram Plot for all Female Dependent Variables", fontsize=25)
# Out:
# Text(0.5, 0.98, 'Histogram Plot for all Female Dependent Variables')

# %% [markdown]
# With regards to the results for the female dependent variables it can be argued, similiar to the male dependent variables results that none seem to follow a normal distribution. What is interesting about the female results is that in both the bill depth and body mass plots there are two to three measuremnts with a high occurance. These measurments (especially for the body mass results) are positioned away from the mean position i.e. middle. This results in a heavy weighting towards the position of the highly occuring measurments and reduces the probability of a normal distribution.

# %%
#Adeile Only Histogram
AdeileData2.hist(figsize=(25,25), color = "purple")
plt.suptitle("Histogram Plot for all Adeile Dependent Variables", fontsize=25)
# Out:
# Text(0.5, 0.98, 'Histogram Plot for all Adeile Dependent Variables')

# %% [markdown]
# It can be seen from the above results that the Adeile dependent variables follow more closely a normal distribution. Within the bill length and flipper length the distribution of results is very reminiscence of a normal distribution with a high concentration of results towards the mean and less the further away.

# %%
#Chinstrap Only Histogram
ChinstrapData2.hist(figsize=(25,25), color = "olive")
plt.suptitle("Histogram Plot for all Chinstrap Dependent Variables", fontsize=25)
# Out:
# Text(0.5, 0.98, 'Histogram Plot for all Chinstrap Dependent Variables')

# %% [markdown]
# Similar to the Adeile results the Chinstrap dependent variables results are shown to follow a normal distribution. Interestingly within the Chinstrap results there appears to be instances where no obsrvations were recorded for a particular value. This could potentially lead to the argument that perhaps the observations below that value are outliers.

# %%
#Gentoo Only Histogram
GentooData2.hist(figsize=(25,25), color = "brown")
plt.suptitle("Histogram Plot for all Gentoo Dependent Variables", fontsize=25)
# Out:
# Text(0.5, 0.98, 'Histogram Plot for all Gentoo Dependent Variables')

# %% [markdown]
# Similar to the previous two sets of results, the Gentoo dependent variables results it can be said, display normal distributions. This once again is due to the high concentration of results in the vicinity of the mean with less on the extremities. What is interesting about the Gentoo results is that there appears to be a high number of occurances of a number of observations. This is in stark contrast to the Chinstrap results in which it was highlighted contained measurements with no observations.

# %% [markdown]
# #### Construction of Histograms with Density Plot of the Dependant Variables by Species
# It is the authors opinion based on the previous results that to best identify if a normal distribution is present analysis should take place at the Species level. This is due to the fact that the overall level and gender level seemed to create a lot of noise with regards to the distribution.
#
# As a result, the author will now analyse the dependant variables through the use of a histogram with density plot. A density plot is a representation of the distribution of a numeric variable (Holtz, 2021). A density plot attempts to visualize the underlying probability distribution of the data by drawing an appropriate continuous curve (Wilke, 2020). The density plot within the histogram is a KDE (Kernel Density Estimate) plot. A KDE aims to estimate the overall shape of a random variable distribution by weighting the distances of all the data points (Van der Plas, 2016). The KDE plot can either be One-Dimensional or Two-Dimensional and is mainly used in the field of non-parametric analysis (Geek for Geeks, 2019).
#
# The author chose to plot the depenant variables on a histogram with density plot as they felt the KDE would visually offer a better understanding if normal distribution was present. Also the author chose to include the histogram again as it was felt it would help the reader identify where the KDE plot was derived from.
#
# It should be noted that for aesthetic purposes and to offer better analysis the following plots will follow the colour scheme which was chosen at the start of the notebook and not the scheme from the pervious scheme.

# %%
#Creation of Histogram with the Density Plot for Bill Length of each of the Species
sns.distplot(AdeileData2.bill_depth_mm, label="Adeile")
sns.distplot(ChinstrapData2.bill_depth_mm, label="Chinstrap")
sns.distplot(GentooData2.bill_depth_mm, label="Gentoo")
plt.xlabel("Bill Depth (Mm)", fontsize=12)
plt.legend(loc='best')
plt.title("Histogram with the Density Plot for Bill Length of each of the Species", fontsize=15)
plt.tight_layout()
plt.show()

# %%
#Creation of Histogram with the Density Plot for Bill Depth of each of the Species
sns.distplot(AdeileData2.bill_length_mm, label="Adeile")
sns.distplot(ChinstrapData2.bill_length_mm, label="Chinstrap")
sns.distplot(GentooData2.bill_length_mm, label="Gentoo")
plt.xlabel("Bill Length (Mm)", fontsize=12)
plt.legend(loc='best')
plt.title("Histogram with the Density Plot for Bill Depth of each of the Species", fontsize=15)
plt.tight_layout()
plt.show()

# %%
#Creation of Histogram with the Density Plot for Body Mass of each of the Species
sns.distplot(AdeileData2.body_mass_g, label="Adeile")
sns.distplot(ChinstrapData2.body_mass_g, label="Chinstrap")
sns.distplot(GentooData2.body_mass_g, label="Gentoo")
plt.xlabel("Body Mass (G)", fontsize=12)
plt.legend(loc='best')
plt.title("Histogram with the Density Plot for Body Mass of each of the Species", fontsize=15)
plt.tight_layout()
plt.show()

# %%
#Creation of Histogram with the Density Plot for Flipper Length of each of the Species
sns.distplot(AdeileData2.flipper_length_mm, label="Adeile")
sns.distplot(ChinstrapData2.flipper_length_mm, label="Chinstrap")
sns.distplot(GentooData2.flipper_length_mm, label="Gentoo")
plt.xlabel("Flipper Length (Mm))", fontsize=12)
plt.legend(loc='best')
plt.title("Histogram with the Density Plot for Flipper Length of each of the Species", fontsize=15)
plt.tight_layout()
plt.show()

# %% [markdown]
# It can be observed that the addition of the KDE plot has greatly enhanced the abillity to analyse if a normal distribution is present. The larger histogram plot and as previously mentioned lighter clour scheme also offer the reader a better opportuninty to investigate the results and measurments.
#
# In terms of the results, it could be argued that the addition of the KDE plot enforces the belief that a normal distribution is present within the depenant variables. This is due to the fact that for the majority of the plot the KDE appears to follow the same path as a normal distribution. It should be noted however that some KDE plots e.g. Chinstrap Body Mass, could be classed as following a laplace distribution.
#
# Also known as a double exponential distribution, a laplace distribution is very similiar to the above mentioned normal distribution in that it is unimodal (has one peak) and symmetrical. However, it has a sharper peak than the Normal distribution (Weisstein, 2020). The Laplace distribution represents the distribution of differences between two independent variables having identical exponential distributions (Science Direct, 2012). The difference between a normal and laplace distribution can be seen in the image below:
#
# <img src="https://www.vosesoftware.com/riskwiki/images/image15_632.gif" alt="Laplace Distribution" width="900"/>
#
# While assumptions can be made with regards to the distribution of the dependant variables from the plots it should be reminded that these are just assumptions. Osborne and Waters (2002) in thier research discovered that: "assumptions can seriously influence Type I and Type II errors, and can result in overestimation or underestimation of the inferential measures and effect sizes," this could lead to biased or skewed results and potentially the dismissal of the analysis. As a result, mathematical models are implemented to confirm visual assumptions. To confirm the pervious visual assumptions the author will implement the Shapiro-Wilks test.

# %% [markdown]
# #### Implementation of the Shapiro-Wilks test
# The Shapiro-Wilks test is a statistical test used to check if a continuous variable follows a normal distribution (Choueiry, 2021). It achieves this by ordering and standardizing the sample i.e. converting the data to a distribution with mean and standard deviation (King et al., 2019). Within the Shapiro-Wilks test a null hypothesis exisits. This null hypothesis is that a variable is normally distributed in some population (JMP, 2021). If the p-value (measure of  marginal significance) is greater than 0.05, then the null hypothesis is accepted i.e. the population is normally distributed. If the p-value is less than or equal to 0.05, then the null hypothesis is rejected i.e. the population is not normally distributed (Van den Berg, 2019). The Shapiro–Wilk test allows the user to determine, with 95% confidence, whether the data fit a normal distribution (ProjectPro, 2022).
#
# The author will now examine each of the dependant variables using the Shapiro-Wilks test.

# %%
#Construction of Shapiro-Wilks test
#Import of shapiro module from scipy.stats
from scipy.stats import shapiro 

#Perform Shapiro-Wilk test for normality on Bill Depth
a = shapiro(AllData.bill_depth_mm)
print("Shapiro-Wilks test for Bill Depth for the All Observations:", a)
# Out:
# Shapiro-Wilks test for Bill Depth for the All Observations: (0.9724070429801941, 3.865591679641511e-06)

# %% [markdown]
# It can be seen that the Shapiro-Wilks test produces two results. The first result is the  test statistic (how consistent your sample data are with the null hypothesis in a hypothesis test(Frost, 2022), the second is the p-value.
#
# From the above results the Shapiro-Wilks test for Bill Depth for all observations returns a statistic score of .97 and a p-value of 3.86e-06 (3.86 * 10^-6) or 0.00000386. As this is less than then 0.05, then the null hypothesis is rejected i.e. there is sufficient evidence to say that the sample does not come from a normal distribution.
#
# The author will now complete the remaining Shapiro-Wilks test on the remaining observations.

# %%
#Perform Shapiro-Wilk test for normality on remaining observations
b = shapiro(MaleData2.bill_depth_mm)
print("Shapiro-Wilks test for Bill Depth for the Male Observations:", b)
c = shapiro(FemaleData2.bill_depth_mm)
print("Shapiro-Wilks test for Bill Depth for the Female Observations:", c)
d = shapiro(AdeileData2.bill_depth_mm)
print("Shapiro-Wilks test for Bill Depth for the Adeile Observations:", d)
e = shapiro(ChinstrapData2.bill_depth_mm)
print("Shapiro-Wilks test for Bill Depth for the Chinstrap Observations:", e)
f = shapiro(GentooData2.bill_depth_mm)
print("Shapiro-Wilks test for Bill Depth for the Gentoo Observations:", f)
# Out:
# Shapiro-Wilks test for Bill Depth for the Male Observations: (0.9475871920585632, 6.551783826580504e-06)
# Shapiro-Wilks test for Bill Depth for the Female Observations: (0.9340441823005676, 3.5193932035326725e-07)
# Shapiro-Wilks test for Bill Depth for the Adeile Observations: (0.9855387806892395, 0.11385617405176163)
# Shapiro-Wilks test for Bill Depth for the Chinstrap Observations: (0.9727429747581482, 0.14178121089935303)
# Shapiro-Wilks test for Bill Depth for the Gentoo Observations: (0.976972758769989, 0.032304953783750534)

# %% [markdown]
# From the results it can be observed that when analysed by Gender both null hypothesis for Bill Depth is rejeced Male Observations p-value of 6.55e-06, Female Observations p-value of 3.51e-07). While when analysed by Species the null hypothesis is accepted by all except Gentoo Observations (Adeile p-value of 0.113, Chinstrap p-value of 0.141 and Gentoo p-value of 0.032). A comparison of the three observations that failed the null hypothesis reveals that the Gentoo Observations were significantly closer to passing the p-value (0.018) that the other two (0.049 minimum)

# %%
#perform Shapiro-Wilk test for normality on Bill Length
g = shapiro(AllData.bill_length_mm)
print("Shapiro-Wilks test for Bill Length for the All observations:", g)
h = shapiro(MaleData2.bill_length_mm)
print("Shapiro-Wilks test for Bill Length for the Male Observations:", h)
i = shapiro(FemaleData2.bill_length_mm)
print("Shapiro-Wilks test for Bill Length for the Female Observations:", i)
j = shapiro(AdeileData2.bill_length_mm)
print("Shapiro-Wilks test for Bill Length for the Adeile Observations:", j)
k = shapiro(ChinstrapData2.bill_length_mm)
print("Shapiro-Wilks test for Bill Length for the Chinstrap Observations:", k)
l = shapiro(GentooData2.bill_length_mm)
print("Shapiro-Wilks test for Bill Length for the Gentoo Observations:", l)
# Out:
# Shapiro-Wilks test for Bill Length for the All observations: (0.974302351474762, 8.373406672035344e-06)
# Shapiro-Wilks test for Bill Length for the Male Observations: (0.9418588876724243, 2.164005763916066e-06)
# Shapiro-Wilks test for Bill Length for the Female Observations: (0.9498902559280396, 7.375533186859684e-06)
# Shapiro-Wilks test for Bill Length for the Adeile Observations: (0.9935796856880188, 0.7375665903091431)
# Shapiro-Wilks test for Bill Length for the Chinstrap Observations: (0.975249707698822, 0.1940952092409134)
# Shapiro-Wilks test for Bill Length for the Gentoo Observations: (0.9730615019798279, 0.013901990838348866)

# %% [markdown]
# Interestingly the Bill Length resluts seem to mimic the Bill Depth resluts i.e. All, Male, Female and Gentoo observations reject the null hypothesis. From this a theory could be developed that accross the four dependant variables a normal distribution do not exist within the All, Male, Female and Gentoo observations. The theory will be further scrutininsed in the results from the remaining two variables.

# %%
#perform Shapiro-Wilk test for normality on Flipper Length
m = shapiro(AllData.flipper_length_mm)
print("Shapiro-Wilks test for Flipper Length for the All observations:", m)
n = shapiro(MaleData2.flipper_length_mm)
print("Shapiro-Wilks test for Flipper Length for the Male Observations:", n)
o = shapiro(FemaleData2.flipper_length_mm)
print("Shapiro-Wilks test for Flipper Length for the Female Observations:", o)
p = shapiro(AdeileData2.flipper_length_mm)
print("Shapiro-Wilks test for Flipper Length for the Adeile Observations:", p)
q = shapiro(ChinstrapData2.flipper_length_mm)
print("Shapiro-Wilks test for Flipper Length for the Chinstrap Observations:", q)
r = shapiro(GentooData2.flipper_length_mm)
print("Shapiro-Wilks test for Flipper Length for the Gentoo Observations:", r)
# Out:
# Shapiro-Wilks test for Flipper Length for the All observations: (0.9511289000511169, 2.888552286250956e-09)
# Shapiro-Wilks test for Flipper Length for the Male Observations: (0.9350131154060364, 6.207598062246689e-07)
# Shapiro-Wilks test for Flipper Length for the Female Observations: (0.9233281016349792, 5.6542496906786255e-08)
# Shapiro-Wilks test for Flipper Length for the Adeile Observations: (0.9932296872138977, 0.6968770027160645)
# Shapiro-Wilks test for Flipper Length for the Chinstrap Observations: (0.9889119863510132, 0.8106710910797119)
# Shapiro-Wilks test for Flipper Length for the Gentoo Observations: (0.963156521320343, 0.0018492583185434341)

# %% [markdown]
# Once again within the Flipper Length results the All, Male, Female and Gentoo observations reject the null hypothesis. This seems to support the previously developed theory and reinforce the normal distribution observed graphically within the Adeile and Chinstrap Observations. Similiar to the Gentoo Observations for Bill Depth the

# %%
#perform Shapiro-Wilk test for normality on Body Mass
s = shapiro(AllData.body_mass_g)
print("Shapiro-Wilks test for Body Mass for the All observations:", s)
t = shapiro(MaleData2.body_mass_g)
print("Shapiro-Wilks test for Body Mass for the Male Observations:", t)
u = shapiro(FemaleData2.body_mass_g)
print("Shapiro-Wilks test for Body Mass for the Female Observations:", u)
v = shapiro(AdeileData2.body_mass_g)
print("Shapiro-Wilks test for Body Mass for the Adeile Observations:", v)
w = shapiro(ChinstrapData2.body_mass_g)
print("Shapiro-Wilks test for Body Mass for the Chinstrap Observations:", w)
x = shapiro(GentooData2.body_mass_g)
print("Shapiro-Wilks test for Body Mass for the Gentoo Observations:", x)
# Out:
# Shapiro-Wilks test for Body Mass for the All observations: (0.9592949151992798, 3.501348544432403e-08)
# Shapiro-Wilks test for Body Mass for the Male Observations: (0.9252845048904419, 1.1886493922474983e-07)
# Shapiro-Wilks test for Body Mass for the Female Observations: (0.9239462614059448, 6.256622953060287e-08)
# Shapiro-Wilks test for Body Mass for the Adeile Observations: (0.9813838005065918, 0.037599965929985046)
# Shapiro-Wilks test for Body Mass for the Chinstrap Observations: (0.9844940900802612, 0.5605263113975525)
# Shapiro-Wilks test for Body Mass for the Gentoo Observations: (0.9864616394042969, 0.2559552490711212)

# %% [markdown]
# From the results we can see that once again the All, Male and Female Observations reject the null hypothesis thereby confirming the earlier statements based on graphical observations. However, the Gentoo Observations this time accept the null hypothesis and dismisses the theory that accross the four dependant variables a normal distribution do not exist. I can be observed though that the null hypothesis is rejected for the Adeile Observations. Similiar to the Gentoo Observations for Bill Depth it is quiet close to passing the p-value (0.013).

# %% [markdown]
# From the statistical results from the Shapiro-Wilks tests it can be stated with confidence that accross the four dependant variables:
# * Normal Distribution does not exist within the Gender obsrvations (All, Male and Female).
# * Normal Distribution exists within all the Chinstrap Observations.
# * Normal Distribution exists within the Bill Depth, Bill Length and Flipper Length for the Adeile Observations.
# * Normal Distribution only exists within the Body Mass for the Gentoo Observations.
#
# While these statement do to a large extent concur with the pervious visual assumptions they also add precision with regards to the resluts. This precision gives the author confidence that, should they be required, the above statements could stand up to scrutiny.

# %%
#Creation of a Scatter Plot to Examine the Relationship Between Flipper Length and Body mass
sns.scatterplot(x="flipper_length_mm", y="body_mass_g", hue="species", data=dt)
plt.xlabel("Flipper Length (Mm)", fontsize=12)
plt.ylabel("Body Mass (G)", fontsize=12)
plt.legend(loc='best', fontsize=10)
plt.title("Relationship Between Flipper Length and Body mass", fontsize=18)
plt.tight_layout()
plt.show()

# %% [markdown]
# From the Scatter plot it can be seen that with the three species a strong positive correltion exists.  What is also interesting is that not only is there a strong positive correltion within the species but it could be argued that as a entire group a strong positive correltion exists. This would lend itself to support the earlier assumption with regards to the species size and their flipper length.

# %%
#Creation of a Scatter Plot to Examine the Relationship Between Bill Depth and Bill Length
sns.scatterplot(x="bill_depth_mm", y="bill_length_mm", hue="species", data=dt)
plt.xlabel("Bill Depth (Mm)", fontsize=12)
plt.ylabel("Bill Length (Mm)", fontsize=12)
plt.legend(loc='best', fontsize=10)
plt.title("Relationship Between Bill Depth and Bill Length", fontsize=18)
plt.tight_layout()
plt.show()

# %% [markdown]
# It can be observed from the bill measurments results that different corelation exists for each species. For Gentoo it could be argued that a strong positive corelation exists, while for Chinstrap the positive corelation would be more seen as moderate to weak. The Adeile results would indicate no corelation exists.
#
# In order to fully examine if any corelation exists within the Adeile bill measurments the author will create a Adeile specific scatter plot and insert a regression line (i.e. a linear approach for modelling the relationship between dependent variables (Majety, 2019).

# %%
#Creation of a Regression Plot to Examine the Relationship Between Bill Depth and Bill Length
sns.regplot(x="bill_depth_mm", y="bill_length_mm", data=AdeileData2, color = "purple")
plt.xlabel("Bill Depth (Mm)", fontsize=12)
plt.ylabel("Bill Length (Mm)", fontsize=12)
plt.title("Relationship Between Bill Depth and Bill Length for Adeile Species", fontsize=18)
plt.tight_layout()
plt.show()

# %% [markdown]
# Upon closer examination it can be seen the in fact a weak positive corelation exists within the Adeile bill measurments. When compared to the othet two species however this would be viewed as very weak given the distance between the data points on the extremities of the upper right and lower left quartile.
#
# From the reults of the bill measurments it could be stated that a positive corelation (however weak) does exist for each species.
#
# Similiar to the previous section the author will now implement a mathematical model to confirm assumptions made. To confirm these assumptions the author will implement the Pearson correlation coefficient test.

# %% [markdown]
# #### Implementation of the Pearson Correlation Coefficient test
# The Pearson Correlation Coefficient test is a statistical test that measures the statistical relationship, or association, between two continuous variables (Laerd, 2020). Named after mathematician Karl Pearson, it is known as the best method of measuring the association between variables of interest because it is based on the method of covariance (direction of the relationship) (HODS, 2021). The reslults offer an insight into the magnitude of the association, or correlation, as well as the direction of the relationship (Schober et al., 2018). The results range from 1 to -1 and the interpretation can be seen in the image below:
#
# <div>
# <img src="attachment:Snip20221114_1.png" width="700"/>
# </div>
#
# The author will now examine each of the dependant variables using the Pearson Correlation Coefficient test.

# %%
x = AdeileData2.bill_depth_mm
y = AdeileData2.bill_length_mm
a = np.corrcoef(x, y)
print("The Pearson correlation coefficients for Adeile bill measurments are\n", a)
# Out:
# The Pearson correlation coefficients for Adeile bill measurments are
#  [[1.         0.38925081]
#  [0.38925081 1.        ]]

# %%
dt.boxplot(column="bill_length_mm", by="species")
plt.title("Bill Length by Species")
plt.xlabel("Species")
plt.ylabel("Bill Length (Mm)")
plt.show()

# %%
from scipy import stats
stats.levene(AdeileData2.bill_length_mm, ChinstrapData2.bill_length_mm, GentooData2.bill_length_mm)
# Out:
# LeveneResult(statistic=2.3678116021336373, pvalue=0.09522423390064622)

# %% [markdown]
# So, Gentoos appear to just be giants, compared to the Adelie and Chinstrap penguins. While Adelie and Chinstraps are similar size-wise as measured by flipper length and body mass, Chinstraps seem to have longer bills and Adelie penguins have stubbier bills (a pug-gein, if you will?). And Gentoos, despite being large overall, have flatter bills than either of the other two species.

# %% [markdown]
# ##  9 References
# ------------------------------------------------------------------------------------------------
# * Berman, H. (2021). *Normal Distribution Calculator*, Stat Trek [online], 01 March, available: https://stattrek.com/online-calculator/normal [Accessed 11 November 2022].
# * Brownlee, J. (2020a). *How to Use StandardScaler and MinMaxScaler Transforms in Python*, Machine Learning Mastery [online], 10 June, availalbe: https://machinelearningmastery.com/standardscaler-and-minmaxscaler-transforms-in-python/ [Accessed 09 November 2022].
# * Brownlee, J. (2020b). *kNN Imputation for Missing Values in Machine Learning*, Machine Learning Mastery [online], 24 June, availalbe: https://machinelearningmastery.com/knn-imputation-for-missing-values-in-machine-learning/ [Accessed 09 November 2022].
# * CFI. (2022a). *Histogram*, Coporate Finance Institute [online], 31 October, available: https://corporatefinanceinstitute.com/resources/excel/histogram/ [Accessed 11 November 2022].
# * CFI. (2022b). *Negatively Skewed Distribution*, Corporate Finance Institute [online], 04 November, availalbe: https://corporatefinanceinstitute.com/resources/knowledge/other/negatively-skewed-distribution/ [Accessed 11 November 2022].
# * Chowdhury, K. (2020). *KNNImputer: A robust way to impute missing values (using Scikit-Learn)*, Analytics Vidhya [online], 14 July, availalbe: https://www.analyticsvidhya.com/blog/2020/07/knnimputer-a-robust-way-to-impute-missing-values-using-scikit-learn/#:~:text=The%20idea%20in%20kNN%20methods,neighbors%20found%20in%20the%20dataset. [Accessed 09 Novmeber 2022].
# * Choueiry, G. (2021). *How to Report the Shapiro-Wilk Test*, Quantifying Health [online], 10 May, availalbe: https://quantifyinghealth.com/report-shapiro-wilk-test/ [Accessed 11 November 2022].
# * Data to Fish. (2021). *Select all Rows with NaN Values in Pandas DataFrame*, Data to Fish [online], 17 July, availalbe: https://datatofish.com/rows-with-nan-pandas-dataframe/ [Accessed 09 November 2022].
# * DataQuest (2017). *SettingwithCopyWarning: How to Fix This Warning in Pandas*, DataQuest [online], 05 July, availalbe: https://www.dataquest.io/blog/settingwithcopywarning/ [Accessed 09 Novmeber 2022].
# * Dash, S. (2022). *Data Exploration and Visualisation Using Palmer Penguins Dataset*, Analytics Vidhya [online], 18 April, https://www.analyticsvidhya.com/blog/2022/04/data-exploration-and-visualisation-using-palmer-penguins-dataset/ [Accessed 08 November 2022].
# * Dou, S. (2020). *How To Create And Use Custom Matplotlib Style Sheet*, Towards Data Science [online], 17 October, available: https://towardsdatascience.com/how-to-create-and-use-custom-matplotlib-style-sheet-9393f498063 [Accessed 09 November 2022].
# * Frost, J. (2018). *Normal Distribution in Statistics*, Statistics by Jim [online], 24 May, available: https://statisticsbyjim.com/basics/normal-distribution/ [Accessed 11 November 2022].
# * Frost, J. (2022). *Test Statistic: Definition, Types & Formulas*, Statistics by Jim [online], 25 July, availalbe: https://statisticsbyjim.com/hypothesis-testing/test-statistic/#comments [Accessed 11 November 2022].
# * Gawali, S. (2021). *How to Deal with Missing Data using Python*, Analytics Vidhya [online], 09 October, available: https://www.analyticsvidhya.com/blog/2021/10/how-to-deal-with-missing-data-using-python/ [Accessed 09 November 2022].
# * Geeks for Geeks. (2019). *KDE Plot Visualization with Pandas and Seaborn*, Geek for Geeks [online], 06 May, availalbe:https://www.geeksforgeeks.org/kde-plot-visualization-with-pandas-and-seaborn/ [Accessed 11 November 2022].
# * Geek for Geeks. (2020a). *Matplotlib.pyplot.hist() in Python*, Geek for Geeks [online], 21 April, availalbe: https://www.geeksforgeeks.org/matplotlib-pyplot-hist-in-python/ [Accessed 11 November 2022].
# * Geek for Geeks. (2020b). *Python | Imputation using the KNNimputer()*, Geek for Geeks [online], 05 September, availalbe: https://www.geeksforgeeks.org/python-imputation-using-the-knnimputer/#:~:text=KNNimputer%20is%20a%20scikit%2Dlearn,with%20mean%20or%20the%20median. [Accessed 09 November 2022].
# * Geek for Geeks. (2021). *Seaborn | Style And Color*, Geek for Geeks [online], 29 Janurary, available: https://www.geeksforgeeks.org/seaborn-style-and-color/ [Accessed 09 November 2022].
# * Ghasemi1, A. and Zahediasl, S. (2012). *Normality Tests for Statistical Analysis: A Guide for Non-Statisticians*, International Journal of Endocrinology and Metabolism, 10(2), pp. 486–489.
# * Glen, S. (2015). *Skewed Distribution: left skewed vs right skewed*, [video online], avaialbe: https://www.youtube.com/watch?v=24YCewQ8s3M [Accessed 11 November 2022].
# * Gorman, K.B. and at al. (2014). *Ecological sexual dimorphism and environmental variability within a community of Antarctic penguins (genus Pygoscelis)*. PloS one, 9(3), pp. 81-90.
# * Gorman K.B. and et al. (2021). *Advancing the Sea Ice Hypothesis: Trophic Interactions Among Breeding Pygoscelis Penguins With Divergent Population Trends Throughout the Western Antarctic Peninsula*, Frontiers in Marine Science, 8(1), pp. 1-8.
# * Hill, A. and et al., (2020). *Release the penguins*, R Studio Education [online], 27 July, available: https://education.rstudio.com/blog/2020/07/palmerpenguins-cran/#meet-the-penguins [Accessed 08 November 2022].
# * Holtz, Y. (2021). *Density Plot*, From Data to Viz [online], 10 April, availalbe: https://www.data-to-viz.com/graph/density.html#:~:text=A%20density%20plot%20is%20a,used%20in%20the%20same%20concept [Accessed 11 November 2022].
# * JMP. (2021). *How do I interpret the Shapiro-Wilk test for normality?*, JMP Statistical Discovery [online], 19 July, availalbe: jmp.com/support/notes/35/406.html [Accessed 11 November 2022].
# * King, A. and et al. (2019) *Inferential Statistics IV: Choosing a Hypothesis Test*, Statistics for Biomedical Engineers and Scientists, 1(7), pp. 14-20.
# * Kumar, N. (2019). *Data Wrangling: Removing Null Values from Dataset in Python using Pandas Library*, The Professionals Point [online], 15 March, available: http://theprofessionalspoint.blogspot.com/2019/03/data-wrangling-removing-null-values.html#:~:text=Removing%20null%20values%20from%20the,learning%20algorithm%20to%20that%20dataset. [Accessed 09 November 2022].
# * Lumen. (2019). *Test for Homogeneity*, Lumen [online], 05 November, availalbe: https://courses.lumenlearning.com/introstats1/chapter/test-for-homogeneity/#:~:text=A%20different%20test%2C%20called%20the,with%20the%20test%20of%20independence. [Accessed 12 November 2022].
# * Madaan, M. (2022). *Handling missing values: Beginners Tutorial*, Naukri Learning [online], 04 April, available: https://www.naukri.com/learning/articles/handling-missing-values-beginners-tutorial/ [Acced 09 November 2022].
# * Maity, A. (2020). *Blog On The Techniques of Data Imputation By Amarjit Maity*, Linkenin [online], 15 October, availalbe: https://www.linkedin.com/pulse/techniques-data-imputation-amarjit-maity [Accessed 09 November 2022].
# * MastersInDataScience.org. (2022). *How to Deal with Missing Data*, MastersInDataScience.org [online], 01 January, availalbe: https://www.mastersindatascience.org/learning/how-to-deal-with-missing-data/#:~:text=When%20dealing%20with%20missing%20data,of%20missing%20data%20is%20low. [Accessed 09 November 2022].
# * McLeod, S. (2019). *Introduction to the Normal Distribution (Bell Curve)*, Simple Psychology [online], 23 March, availalbe: https://www.simplypsychology.org/normal-distribution.html [Accessed 11 November 2022].
# * Mishra, P. et al. (2012). *Descriptive statistics and normality tests for statistical data*, Annals of Cardiac Anaesthesia, 22(1), pp. 67-72.
# * OECD. (2002). *Homogeneity Definition*, OECD [online], 19 May, availalbe: https://stats.oecd.org/glossary/detail.asp?ID=3673 [Accessed 12 November 2022].
# * Osborne, J. W. and  Waters, E. (2002). *Four assumptions of multiple regression that researchers should always test*, Practical Assessment, Research, and Evaluation, 8(1), pp.2.
# * ProjectPro. (2022). *What is shapiro test? How to perform it in R*, ProjectPro [online], 07 July, availalbe: https://www.projectpro.io/recipes/what-is-shapiro-test-perform-it-r [Accessed 11 November 2022].
# * Rishabh. (2017). *Purpose of "%matplotlib inline"*, Stack Overflow [online], 26 March, available: https://stackoverflow.com/questions/43027980/purpose-of-matplotlib-inline/43028034 [Accessed 09 November 2022].
# * Simplilearn. (2022). *What Is Data Wrangling? Benefits, Tools, Examples and Skills*, Simplilearn [online], 12 July, available: https://www.simplilearn.com/data-wrangling-article#:~:text=Data%20wrangling%20is%20the%20process%20of%20removing%20errors%20and%20combining,analysis%20is%20becoming%20increasingly%20necessary [Accessed 09 November 2022].
# * Singhal, S. (2021). *Defining, Analysing, and Implementing Imputation Techniques*, Analytics Vidhya [online], 21 June, available: https://www.analyticsvidhya.com/blog/2021/06/defining-analysing-and-implementing-imputation-techniques/#:~:text=What%20is%20Imputation%3F,data%2Finformation%20of%20the%20dataset [Accessed 09 November 2022].
# * Schork, J. (2019). *Mean Imputation for Missing Data (Example in R & SPSS)*, Statistics Globe [online], 24 September, availalbe: https://statisticsglobe.com/mean-imputation-for-missing-data/ [Accessed 09 Novmeber 2022].
# * Solomon, B. (2018). * Python Histogram Plotting: NumPy, Matplotlib, Pandas & Seaborn*, Real Python [online], 26 March, available: https://realpython.com/python-histograms/ [Accessed 11 November 2022].
# * Stack Overflow. (2012). *Hide all warnings in ipython*, Stack Overflow [online], 27 January, availalbe: https://stackoverflow.com/questions/9031783/hide-all-warnings-in-ipython [Accessed 09 November 2022].
# * Swalin, A. (2018). *How to Handle Missing Data*, Towards Data Science [online], 31 January, availalbe: https://towardsdatascience.com/how-to-handle-missing-data-8646b18db0d4 [Accessed 09 November 2022].
# * The Data Detective. (2019). *Preprocessing: Encode and KNN Impute All Categorical Features Fast*, Towards Data Science [online], 19 November, available: https://towardsdatascience.com/preprocessing-encode-and-knn-impute-all-categorical-features-fast-b05f50b4dfaa [Accessed 09 November 2022].
# * Tirendaz Academy. (2022). *Penguin Dataset: Data Visualization with Seaborn*, Kaggle [online], 20 July, available: https://www.kaggle.com/code/tirendazacademy/penguin-dataset-data-visualization-with-seaborn [Accessed 09 November 2022].
# * Tsai, E. (2021). *Build a Python project using Pandas and Seaborn*, Medium [online], 01 September, availalbe: https://medium.com/@marvelouskgc/build-a-penguin-project-using-pandas-and-seaborn-eugene-tsai-e4b7e0b499ea [Accessed 09 November 2022].
# * Tutor2U. (2019). *Skewed Distribution*, Tutor2U [online], 15 June, avaialbe: https://www.tutor2u.net/psychology/topics/skewed-distribution [Accessed 11 November 2022].
# * Van den Berg, R. (2019). *SPSS Shapiro-Wilk Test – Quick Tutorial with Example*, SPSS Tutorials [online], 16 April, available: https://www.spss-tutorials.com/spss-shapiro-wilk-test-for-normality/ [Accessed 11 Novmeber 2022].
# * Van der Plas, J. (2016). *Python Data Science Handbook*, New York: O'Reilly Media, Inc.
# * Vose Software. (2019). *Laplace Distribution*, Vose Software [online], 15 March, availalbe: https://www.vosesoftware.com/riskwiki/Laplacedistribution.php [Accessed 11 November 2022].
# * w3shools.com. (2019). *Normal (Gaussian) Distribution*, w3shools.com [online], 12 April, availalbe: https://www.w3schools.com/python/numpy_random_normal.asp [Accessed 11 November 2022].
# * Weisstein, E.W. (2016). *What is a Normal distribution?*, Statistics How To [online], 17 October, availalbe: https://www.statisticshowto.com/probability-and-statistics/normal-distributions/ [Accessed 11 November 2022].
# * Weisstein, E. (2018). *Skewed Distribution: Definition, Examples*, Statistics How To [online], 26 October, avaialbe: https://www.statisticshowto.com/probability-and-statistics/skewed-distribution/ [Accessed 11 November 2022].
# * Weisstein, E. (2020). *Laplace Distribution / Double Exponential*, Statistics How To [online], 12 January, availalbe: https://www.statisticshowto.com/laplace-distribution-double-exponential/ [Accessed 11 November 2022].
# * Wilke, C. (2020). *Visualizing distributions: Histograms and density plots*, Claus Wilke [online], 19 September, avaialble: https://clauswilke.com/dataviz/histograms-density-plots.html [Accessed 11 November 2022].
# * Zach, M. (2021). *5 Examples of Positively Skewed Distributions*, Statology [online], 19 May, availalbe: https://www.statology.org/positively-skewed-distribution-examples/ [Accessed 11 November 2022].
#
#
#
# Analytics Vidhya
#
#
#
#
# * Cherry, K. (2022). *What Is a Correlation?*, Very Well Mind [online], 15 April, availalbe: https://www.verywellmind.com/what-is-correlation-2794986 [Accessed 12 November 2022].
# * JMP. (2022). *Correlation*, JMP Statistical Discovery [online], 10 May, availalbe: https://www.jmp.com/en_ca/statistics-knowledge-portal/what-is-correlation.html#:~:text=Correlation%20is%20a%20statistical%20measure,statement%20about%20cause%20and%20effect. [Accessed 12 November 2022].
# * Majety, A. (2019), *Linear Regression*, Linkenin [online], 12 June, availalbe: https://www.linkedin.com/pulse/linear-regression-abhinav-majety/ [Accessed 12 November 2022].
# * Laerd. (2020). *Pearson correlation coefficient*, Laerd Statistics [online], 12 March, available: https://statistics.laerd.com/statistical-guides/pearson-correlation-coefficient-statistical-guide.php [Accessed 12 November 2022].
# * HODS. (2021). *Karl Pearson: Creator of Correlation*, HODS [online], 06 March, availalbe: https://www.historyofdatascience.com/karl-pearson-creator-of-correlation/ [Accessed 12 November 2022].
# * Schober, P. and et al. (2018). *Correlation Coefficients: Appropriate Use and Interpretation*, Anesthesia & Analgesia, 126(5), pp. 1763-1768.

# %% [markdown]
# ##  10 Bibliography
# ------------------------------------------------------------------------------------------------
# * Geek for Geeks. (2022). *Check for NaN in Pandas DataFrame*, Geeks for Geeks [online], 26 August, availalbe: geeksforgeeks.org/check-for-nan-in-pandas-dataframe/ [Accessed 09 November 2022].
# * Gupta, D. (2018). *Pandas DataFrame: Playing with CSV files*, Medium [online], 02 November, availalbe: https://towardsdatascience.com/pandas-dataframe-playing-with-csv-files-944225d19ff [Accessed 08 November 2022].
# * Ha, J. (2009). *How can I check for NaN values?*, Stack Overflow [online], 03 June, availalbe: https://stackoverflow.com/questions/944700/how-can-i-check-for-nan-values [Accessed 09 November 2022].
# * Horst, S. et al. (2022). *The R Journal: Palmer Archipelago Penguins Data in the palmerpenguins R Package - An Alternative to Anderson's Irises*, The R Journal, 1(1), pp. 7-16.
# * Rai, S. (2019). *3 Methods to Handle Missing Data*, Oracle [online], 28 Februry, available: https://blogs.oracle.com/ai-and-datascience/post/3-methods-to-handle-missing-data [Accessed 09 November 2022].
# * Science Direct. (2012). *Laplace Distribution*, Probability and Random Processes, 1(2) pp. 5-14.
# * Stobierski, T. (2021). *DATA WRANGLING: WHAT IT IS & WHY IT’S IMPORTANT*, Harvard Business School [online], 19 January, availalbe: https://online.hbs.edu/blog/post/data-wrangling [Accessed 09 November 2022].

# %%
jupyter nbconvert --execute --to pdf Penguin.ipynb
